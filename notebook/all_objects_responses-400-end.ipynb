# %%
import os
from backoff import on_exception, expo
import json
import requests
from collections import Counter
from datetime import datetime
from ratelimit import limits, sleep_and_retry, RateLimitException
import time
import urllib.request
import asyncio
import aiohttp
import nest_asyncio
from async_timeout import timeout
from requests.exceptions import HTTPError

# %%
data_path = "D:\\METIS\\data\\"

met_objects = []

# %%
url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects'
response = requests.get(url, allow_redirects=False)
all_objects = json.loads(response.text)
objectIDs = all_objects['objectIDs']

# %%
len(objectIDs)
# Out:
# 474632

# %%
def get_object_details(object_id, img_url=True):
    url ='https://collectionapi.metmuseum.org/public/collection/v1/objects/{}'.format(object_id)
    response = requests.get(url, timeout=10)
    response_json = json.loads(response.text)
    met_objects.append(response_json)

# %%
met_objects = []

# %% [markdown]
# start = datetime.now()
#
# for i, object_id in enumerate(objectIDs):
#     if i % 1000 == 0:
#         with open(data_path + "images_saved.json", "w") as write_file:
#             json.dump(images_saved, write_file)
#
#         with open(data_path + "met_objects.json", "w") as write_file:
#             json.dump(met_objects, write_file)
#
#         print("{}: {} elapsed".format(i, datetime.now() - start))
#
#     try:
#         img_url = get_object_details(object_id)
#         get_image(object_id, img_url)
#
#     except:
#         pass
#    # print(i, object_id)

# %%
start = datetime.now()

for i, object_id in enumerate(objectIDs[400000:len(objectIDs)]):
    if i % 1000 == 0:
        with open(data_path + "all_objects_12-6_400-end.json", "w") as write_file:
            json.dump(met_objects, write_file)  
            
        print("{}: {} elapsed".format(i, datetime.now() - start))
            
    try:
        get_object_details(object_id, img_url=False)
        
    except:
        pass
# Out:
# 0: 0:00:00.014999 elapsed
# 1000: 0:03:31.680551 elapsed
# 2000: 0:07:18.492934 elapsed
# 3000: 0:11:05.925852 elapsed
# 4000: 0:14:55.336636 elapsed
# 5000: 0:18:45.251246 elapsed
# 6000: 0:22:44.174574 elapsed
# 7000: 0:26:29.931446 elapsed
# 8000: 0:30:17.841368 elapsed
# 9000: 0:34:11.491287 elapsed
# 10000: 0:38:00.807026 elapsed
# 11000: 0:41:54.319139 elapsed
# 12000: 0:45:51.458565 elapsed
# 13000: 0:50:01.641566 elapsed
# 14000: 0:54:52.850352 elapsed
# 15000: 0:59:18.343869 elapsed
# 16000: 1:03:40.196235 elapsed
# 17000: 1:08:29.968491 elapsed
# 18000: 1:13:11.241487 elapsed
# 19000: 1:17:45.172772 elapsed
# 20000: 1:22:32.413300 elapsed
# 21000: 1:27:16.081341 elapsed
# 22000: 1:32:11.572952 elapsed
# 23000: 1:37:15.929431 elapsed
# 24000: 1:42:10.375814 elapsed
# 25000: 1:47:05.116699 elapsed
# 26000: 1:51:59.295222 elapsed
# 27000: 1:57:21.979057 elapsed
# 28000: 2:02:24.072344 elapsed
# 29000: 2:07:59.620860 elapsed
# 30000: 2:12:44.457378 elapsed
# 31000: 2:17:15.225380 elapsed
# 32000: 2:22:19.825378 elapsed
# 33000: 2:27:37.976744 elapsed
# 34000: 2:32:48.434245 elapsed
# 35000: 2:38:04.395744 elapsed
# 36000: 2:43:34.251213 elapsed
# 37000: 2:49:20.325210 elapsed
# 38000: 2:54:32.220215 elapsed
# 39000: 2:59:33.672852 elapsed
# 40000: 3:04:55.855688 elapsed
# 41000: 3:10:28.960692 elapsed
# 42000: 3:16:14.452249 elapsed
# 43000: 3:22:02.422347 elapsed
# 44000: 3:28:24.751563 elapsed
# 45000: 3:34:48.173560 elapsed
# 46000: 3:41:12.008562 elapsed
# 47000: 3:47:39.776287 elapsed
# 48000: 3:53:59.380816 elapsed
# 49000: 4:00:21.203762 elapsed
# 50000: 4:06:41.186136 elapsed
# 51000: 4:13:11.826785 elapsed
# 52000: 4:19:18.350145 elapsed
# 53000: 4:25:20.913815 elapsed
# 54000: 4:30:54.385083 elapsed
# 55000: 4:36:32.873083 elapsed
# 56000: 4:41:59.470081 elapsed
# 57000: 4:47:24.879410 elapsed
# 58000: 4:53:17.114416 elapsed
# 59000: 4:59:26.490733 elapsed
# 60000: 5:06:09.668685 elapsed
# 61000: 5:13:12.038020 elapsed
# 62000: 5:18:48.910475 elapsed
# 63000: 5:25:07.182890 elapsed
# 64000: 5:31:37.573870 elapsed
# 65000: 5:38:35.379602 elapsed
# 66000: 5:45:51.582174 elapsed
# 67000: 5:53:06.109396 elapsed
# 68000: 5:59:31.425334 elapsed
# 69000: 6:05:20.788728 elapsed
# 70000: 6:10:50.335312 elapsed
# 71000: 6:17:29.710232 elapsed
# 72000: 6:24:21.650846 elapsed
# 73000: 6:32:00.036318 elapsed
# 74000: 6:39:43.685997 elapsed

# %%
with open(data_path + "all_objects_12-6_400-end.json", "w") as write_file:
    json.dump(met_objects, write_file)

# %%
print("Finished", datetime.now() - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8916f958633d> in <module>
# ----> 1 print(Finished, datetime.now() - start)
#
# NameError: name 'Finished' is not defined
