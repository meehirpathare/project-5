# %%
import matplotlib.pyplot as plt
import numpy as np

from helpers import get_palette, simplify_axis, closest_on_palette
from itertools import permutations 
from datetime import datetime

# %%
data_path = "D:\\METIS\\data\\"
image_path = "D:\\METIS\\images\\"
palette = get_palette()

# %%
ax = np.ones(256)

# %%
[arr, centers] = simplify_axis(ax=np.ones(256), size=3, return_arr=True, return_centers=True)

# %%
simplified_colors = []
for i in centers:
    for j in centers:
        for k in centers:
            color = (i, j, k)
            simplified_colors.append(color)

len(simplified_colors)
# Out:
# 614125

# %%
simple_cmap = {}

# %%
start = datetime.now()
for i,color in enumerate(simplified_colors):
    
    simple_cmap[color] = closest_on_palette(color, palette)
    
    if i % 5000 == 0:
        with open(data_path + "simple_cmap.json", "w") as write_file:
            json.dump(simple_cmap, write_file) 
            
        print("{}: {} elapsed".format(i, datetime.now() - start))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-06317e034d7e> in <module>
# ----> 1 start = datetime.now()
#       2 for i,color in enumerate(simplified_colors):
#       3
#       4     simple_cmap[color] = closest_on_palette(color, palette)
#       5
#
# NameError: name 'datetime' is not defined

# %%
with open(data_path + "simple_cmap.json", "w") as write_file:
            json.dump(simple_cmap, write_file)

# %%
len(simple_cmap)
