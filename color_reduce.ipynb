# %%
import imghdr
from PIL import Image 
import os
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg 
import json
import numpy as np
from skimage import io
from helpers import (get_dims, color_distance, display_color, palette_distance, 
                     closest_on_palette, make_color_list, make_color_map, get_channel, get_dominant_color)
import math
from colorthief import ColorThief
# %matplotlib inline

# %%
data_path = os.getcwd() + "\\data\\"
json_path = data_path + "color_palette.json" 

with open(json_path, "r", encoding='utf-8') as json_file: 
    palette = json.load(json_file)
    
palette
color_list = np.array([tuple(x) for x in palette.values()], dtype=np.uint8)

# %%
img = mpimg.imread('test_image.jpg').astype('uint8')
plt.imshow(img)
plt.axis('off')
plt.show()
get_dims(img)

# %%
display_color(color_list, figsize = (10, 10), dpi = 10, shape=(4, 5))

# %%
color_thief = ColorThief('test_image.jpg')
dominant_color = np.array(color_thief.get_color(quality=10)).reshape(1, 1, 3)
color_list_2 = np.array(color_thief.get_palette(color_count=21), dtype=np.uint8)
dom = get_dominant_color('test_image.jpg')

# %%
d1 = tuple(dominant_color[0][0])
d2 = tuple(dom[0][0])

print("Dominant from ColorThief : {} \nDominant from my_func: {}".format(d1, d2))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1)
ax1.set_title('ColorThief: {}'.format(d1))
ax1.imshow(dominant_color)
ax1.set_axis_off()
ax2.imshow(dom)
ax2.set_axis_off()
ax2.set_title('my_func: {}'.format(d2))
plt.show()

# %%
grid = display_color(color_list_2, figsize = (8, 8), dpi = 10, shape=(4, 5), return_vals=True)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1)
fig.set_figheight(15)
fig.set_figwidth(15)
ax1.imshow(img)
ax1.set_axis_off()
ax2.imshow(grid)
ax2.set_axis_off()

plt.show()

# %%
c_list = make_color_list('all_colors.txt')

# %%
step = 10e4
low = 0
high = step

lowers = []
uppers = []

while low < len(c_list):
    lowers.append(int('{:06.0f}'.format(low)))
    low += step

while high < len(c_list):
    uppers.append(int('{:06.0f}'.format(high -1)))
    #print(type('{:.0f}'.format(high)))
    high +=  step

uppers.pop(-1)
uppers.append(len(c_list))

lims = list(zip(lowers, uppers))
for i, j in lims:
    print("make_color_map(c_list, palette, data_path + 'cmap_{}_to_{}.txt')".format(i, j))
# Out:
# make_color_map(c_list, palette, data_path + 'cmap_0_to_99999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_100000_to_199999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_200000_to_299999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_300000_to_399999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_400000_to_499999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_500000_to_599999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_600000_to_699999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_700000_to_799999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_800000_to_899999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_900000_to_999999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1000000_to_1099999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1100000_to_1199999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1200000_to_1299999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1300000_to_1399999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1400000_to_1499999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1500000_to_1599999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1600000_to_1699999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1700000_to_1799999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1800000_to_1899999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_1900000_to_1999999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2000000_to_2099999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2100000_to_2199999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2200000_to_2299999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2300000_to_2399999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2400000_to_2499999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2500000_to_2599999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2600000_to_2699999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2700000_to_2799999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2800000_to_2899999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_2900000_to_2999999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_3000000_to_3099999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_3100000_to_3199999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_3200000_to_3299999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_3300000_to_3399999.txt')
# make_color_map(c_list, palette, data_path + 'cmap_3400000_to_3499999.txt')
# make_color_map(c_list, palette, data_path + 'cmap