# %%
import zipfile
import os

# %%
image_path = "D:\\METIS\\downscaled\\"
data_path = "D:\\METIS\\data\\"

# %%
list_of_images = os.listdir(image_path)

# %%
len(list_of_images)
# Out:
# 8760

# %%
list_of_images[0:10]
# Out:
# ['resized_DT5256.jpg',
#  'resized_DT5389.jpg',
#  'resized_DT5568.jpg',
#  'resized_DT7052.jpg',
#  'resized_RT790A.jpg',
#  'resized_RT807A.jpg',
#  'resized_TP446A.jpg',
#  'resized_CI38.23.23a_F.jpg',
#  'resized_66396.jpg',
#  'resized_C.I.39.13.104_F.JPG']

# %%
len(list_of_images[0:5000])
# Out:
# 5000

# %%
img_files = [image_path + x for x in list_of_images]

# %%
img_files[0]
# Out:
# 'D:\\METIS\\downscaled\\resized_DT5256.jpg'

# %%
with zipfile.ZipFile(data_path + 'first_5000.zip', 'w') as zipMe:        
    for file in img_files[0:5000]:
        zipMe.write(file, compress_type=zipfile.ZIP_DEFLATED)
