# %%
import imghdr
from PIL import Image 
import os
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg 
import json
import numpy as np
from skimage import io
from helpers import (get_dims, color_distance, display_color, palette_distance, 
                     closest_on_palette, get_channel, get_dominant_color)
import math
from colorthief import ColorThief
from joblib import Parallel, delayed
import multiprocessing
from datetime import datetime
import asyncio

# %matplotlib inline

# %%
data_path =  os.getcwd() + "\\data\\"
image_path = "D:\\METIS\\images\\"

# %%
palette = {
        'sky blue': (113, 213, 248),'ultramarine': (60, 124, 246),'medium blue': (15, 72, 175),'dark blue': (25, 42, 114),
        'violet': (33, 19, 70),'teal': (14, 67, 73),'green': (15, 66, 35),'leaf green': (88, 135, 31),
        'light green': (154, 193, 45), 'yellow': (255, 252, 35),'orange': (230, 156, 23),'dark orange': (235, 105, 21),
        'vermillion': (216, 68, 14),'red': (205, 19, 14),'fuchsia': (157, 52, 105),'purple': (107, 32, 86),
        'dark purple': (84, 20, 57),'dark grey': (110, 110, 110),'light grey': (220, 220, 220),'pale grey': (240, 240, 240)
        }

# %%
def closest_on_palette(input_color, palette):
    dists = palette_distance(input_color, palette)
    min_index = np.argmin(dists)
    return list(palette.keys())[min_index]  

def make_color_list(save=False, filename='all_colors.txt'):
    all_colors = -1 * np.ones((256**3), dtype=object)
    pos = 0
    
    for i in range(0, 256):
        for j in range(0,256):
            for k in range(0, 256):  
                all_colors[pos] = (i, j, k)
                pos += 1
    
    if save == True:
        with open(filename, 'w') as f:
            f.write(str(cmap))
    return all_colors

# %%
all_colors = make_color_list()

# %%
cmap = {}

# %%
start = datetime.now()
for i in range(4000000):
    
    if i % 2500 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_0_to_4m.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
# Out:
# 0: 0:00:00 elapsed
# 2500: 0:00:19.348080 elapsed
# 5000: 0:00:38.784972 elapsed
# 7500: 0:00:57.991780 elapsed
# 10000: 0:01:17.745937 elapsed
# 12500: 0:01:37.167042 elapsed
# 15000: 0:01:56.452173 elapsed
# 17500: 0:02:16.163681 elapsed
# 20000: 0:02:35.577243 elapsed
# 22500: 0:02:55.920615 elapsed
# 25000: 0:03:16.780618 elapsed
# 27500: 0:03:36.504656 elapsed
# 30000: 0:04:04.212446 elapsed
# 32500: 0:04:25.605380 elapsed
# 35000: 0:04:46.968371 elapsed
# 37500: 0:05:11.305825 elapsed
# 40000: 0:05:31.844647 elapsed
# 42500: 0:05:55.574867 elapsed
# 45000: 0:06:15.907852 elapsed
# 47500: 0:06:35.515004 elapsed
# 50000: 0:06:56.813699 elapsed
# 52500: 0:07:17.673570 elapsed
# 55000: 0:07:38.270356 elapsed
# 57500: 0:08:05.269655 elapsed
# 60000: 0:08:24.977866 elapsed
# 62500: 0:08:46.233160 elapsed
# 65000: 0:09:06.992761 elapsed
# 67500: 0:09:27.930167 elapsed
# 70000: 0:09:51.864451 elapsed
# 72500: 0:10:16.171481 elapsed
# 75000: 0:10:39.431258 elapsed
# 77500: 0:11:03.721498 elapsed
# 80000: 0:11:31.234131 elapsed
# 82500: 0:11:54.218814 elapsed
# 700000: 2:07:40.447052 elapsed
# 702500: 2:08:09.870871 elapsed
# 705000: 2:08:39.015403 elapsed
# 707500: 2:09:07.972564 elapsed
# 710000: 2:09:37.315062 elapsed
# 712500: 2:10:02.866996 elapsed
# 715000: 2:10:29.007803 elapsed
# 717500: 2:10:55.101152 elapsed
# 720000: 2:11:20.936823 elapsed
# 722500: 2:11:47.193901 elapsed
# 725000: 2:12:16.354952 elapsed
# 727500: 2:12:50.537958 elapsed
# 730000: 2:13:35.166239 elapsed
# 732500: 2:14:41.094697 elapsed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a93d82c2aaac> in <module>
#       8             f.write(str(cmap))
#       9
# ---> 10     cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
#
# <ipython-input-4-c6319d852698> in closest_on_palette(input_color, palette)
#       1 def closest_on_palette(input_color, palette):
# ----> 2     dists = palette_distance(input_color, palette)
#       3     min_index = np.argmin(dists)
#       4     return list(palette.keys())[min_index]
#       5
#
# ~\Documents\GitHub\project-5\helpers.py in palette_distance(input_color, palette)
#      74
#      75     for count, color in enumerate(palette.items()):
# ---> 76         dists[count] = color_distance(input_color, color[1])
#      77     return dists
#      78
#
# ~\Documents\GitHub\project-5\helpers.py in color_distance(color_1, color_2)
#      34
#      35     # Find the color difference
# ---> 36     delta_e = delta_e_cie2000(color1_lab, color2_lab)
#      37
#      38     return delta_e
#
# ~\anaconda3\lib\site-packages\colormath\color_diff.py in delta_e_cie2000(color1, color2, Kl, Kc, Kh)
#      75     color1_vector = _get_lab_color1_vector(color1)
#      76     color2_matrix = _get_lab_color2_matrix(color2)
# ---> 77     delta_e = color_diff_matrix.delta_e_cie2000(
#      78         color1_vector, color2_matrix, Kl=Kl, Kc=Kc, Kh=Kh)[0]
#      79     return numpy.asscalar(delta_e)
#
# ~\anaconda3\lib\site-packages\colormath\color_diff_matrix.py in delta_e_cie2000(lab_color_vector, lab_color_matrix, Kl, Kc, Kh)
#     148     diff_h2p_h1p = h2p - h1p
#     149     delta_hp = diff_h2p_h1p + (numpy.fabs(diff_h2p_h1p) > 180) * 360
# --> 150     delta_hp -= (h2p > h1p) * 720
#     151
#     152     delta_Lp = lab_color_matrix[:, 0] - L
#
# KeyboardInterrupt:

# %% [markdown]
# for i in range(4000000, 8000000):
#
#     if i % 100000 == 0:
#         print("{}: {} elapsed".format(i, datetime.now() - start))
#
#         with open(data_path + 'test_4_to_8m.txt', 'w') as f:
#             f.write(str(cmap))
#
#     cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)

# %% [markdown]
# for i in range(8000000, 12000000):
#
#     if i % 100000 == 0:
#         print("{}: {} elapsed".format(i, datetime.now() - start))
#
#         with open(data_path + 'test_8_to_12m.txt', 'w') as f:
#             f.write(str(cmap))
#
#     cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)

# %%
cmap = {}
start = datetime.now()
for i in range(12000000, len(all_colors)):
    
    if i % 2500 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_12_to_end.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)

# %%
with open(data_path + 'rgb_closest.txt', 'w') as f:
            f.write(str(cmap))
        
print("Finished")
