# %% [markdown]
# ### <font color ='blue'> *This notebook covers the process of getting table data from BigQuery* </font>
# **Tools and Packages:** `bigQuery`,`BigQuery Storage`, `pandas`, and `pandas-gbq`

# %%
import os
from google.cloud import bigquery
from google.cloud.bigquery import magics
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas_gbq as pd_gbq
from matplotlib import rcParams

# %%
# %load_ext google.cloud.bigquery

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:\\Users\\Meehir\\Documents\\GitHub\\bQ-key.json"

# %%
# %%bigquery df_met_imgs --use_bqstorage_api
# SELECT * FROM `bigquery-public-data.the_met.images`
# Out:
# Executing query with job ID: bc75652c-2aae-4e96-a2cf-f7982e157021
# Query executing: 828.08s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d731a8b61a72> in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', 'df_met_imgs --use_bqstorage_api', 'SELECT * FROM `bigquery-public-data.the_met.images` \n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\magics\magics.py in _cell_magic(line, query)
#     669
#     670         try:
# --> 671             query_job = _run_query(client, query, job_config=job_config)
# ...

# %%
# %%bigquery df_met_objects --use_bqstorage_api
# SELECT * FROM `bigquery-public-data.the_met.objects`

# %%
# %%bigquery df_met_vision_api --use_bqstorage_api
# SELECT * FROM `bigquery-public-data.the_met.vision_api_data`
