# %%
import imghdr
from PIL import Image 
import os
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg 
import json
import numpy as np
from skimage import io
from helpers import get_dims, color_distance, display_color
# %matplotlib inline

# %%
data_path = os.getcwd() + "\\data\\"
data_path

# %%
json_path = data_path + "color_palette.json" 

with open(json_path, "r", encoding='utf-8') as json_file: 
    data = json.load(json_file)

print(data)

# %%
vals = [tuple(x) for x in data.values()]

# %%
# Read Images 
img = mpimg.imread('test_image.jpg') 
  
# Output Images 
plt.imshow(img)

# %%
get_dims(img)
# Out:
# (2809, 3811)

# %%
# arbitrary pixels
c1 = img[1000][400]
c2 = img[400][1000]

color_distance(c1, c2)
# Out:
# 33.174476302712904

# %%
swapped = {}
for key, value in data.items():
    swapped[tuple(value)] = key

# %%
with open(data_path + "swapped_key_dict_palette.txt", "w", encoding='utf-8') as outfile: 
    outfile.write(str(swapped))

# %%
vals = data.values()
vals = [tuple(x) for x in vals]

# %%
palette = np.array(vals, dtype=np.uint8)

m, n = 4, 5
d = (1, len(palette))
indices = np.array(list(range(0, len(palette)))).reshape(m, n)

plt.figure()
io.imshow(palette[indices])
plt.axis('off')

plt.show()

# %%
from helpers import display_color

# %%
display_color(palette)

# %%
display_color(palette)

# %%
display_color(palette, figsize = (10, 10), dpi = 10, shape=(6, 5))
