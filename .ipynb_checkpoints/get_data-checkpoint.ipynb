# %%
import os
from backoff import on_exception, expo
import json
import requests
from collections import Counter
from datetime import datetime
from ratelimit import limits, sleep_and_retry, RateLimitException
import time
import urllib.request
import asyncio
import aiohttp
import nest_asyncio
from async_timeout import timeout
from requests.exceptions import HTTPError

# %%
data_path = "D:\\METIS\\data\\"
image_path = "D:\\METIS\\images\\"

# %%
url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects'
response = requests.get(url, allow_redirects=True)
all_objects = json.loads(response.text)
objectIDs = all_objects['objectIDs']

with open(data_path + 'all_objects.txt', 'w', encoding='utf8') as f:
    f.write(str(all_objects))

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@sleep_and_retry
@on_exception(expo, RateLimitException, max_tries=8)
@limits(calls=300, period=300)
@background
def get_object_details(object_id):
    url ='https://collectionapi.metmuseum.org/public/collection/v1/objects/{}'.format(object_id)
    response = requests.get(url, timeout=10)
    response_json = json.loads(response.text)
    met_objects.append(response_json)
    return response_json['primaryImage']
            
def get_image(filename,img_url):
    obj_id = img_url.split('/')[-1]
    im = urllib.request.urlretrieve(url, filename, timeout=10)
    images_saved.append({
                        'objectID': obj_id,
                        'url': img_url,
                        'filename': filename
                        })

# %%
range(10)
objectIDs[0]
# Out:
# 1

# %%
len(objectIDs)
# Out:
# 474495

# %%
images_saved = []
met_objects = []

# %%
start = datetime.now()
for i in range(len(objectIDs)):
    obj_id = objectIDs[i]
    
    if i % 1000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        with open(data_path + "images_saved.json", "w") as write_file:
            json.dump(images_saved, write_file)   
            
        with open(data_path + "met_objects.json", "w") as write_file:
            json.dump(met_objects, write_file)   
        
    try:
        img_url = get_object_details(obj_id)
        get_image(image_path + "{}.jpg".format(obj_id, img_url), img_url)
        
    except:
        pass
# Out:
# 0: 0:00:00 elapsed
# 10: 0:00:00.109155 elapsed
# 20: 0:00:00.121158 elapsed
# 30: 0:00:00.136473 elapsed
# 40: 0:00:00.156164 elapsed
# 50: 0:00:00.171163 elapsed
# 60: 0:00:00.187164 elapsed
# 70: 0:00:00.210164 elapsed
# 80: 0:00:00.226165 elapsed
# 90: 0:00:00.262165 elapsed

# %%
print(len(met_objects), len(saved_images))
# Out:
# 0 {'objectID': 2, 'isHighlight': False, 'accessionNumber': '1980.264.5', 'accessionYear': '1980', 'isP
# 1 {'objectID': 6, 'isHighlight': False, 'accessionNumber': '67.265.12', 'accessionYear': '1967', 'isPu
# 2 {'objectID': 3, 'isHighlight': False, 'accessionNumber': '67.265.9', 'accessionYear': '1967', 'isPub
# 3 {'objectID': 7, 'isHighlight': False, 'accessionNumber': '67.265.13', 'accessionYear': '1967', 'isPu
# 4 {'objectID': 4, 'isHighlight': False, 'accessionNumber': '67.265.10', 'accessionYear': '1967', 'isPu
# 5 {'objectID': 5, 'isHighlight': False, 'accessionNumber': '67.265.11', 'accessionYear': '1967', 'isPu
# 6 {'objectID': 1, 'isHighlight': False, 'accessionNumber': '1979.486.1', 'accessionYear': '1979', 'isP
# 7 {'objectID': 8, 'isHighlight': False, 'accessionNumber': '67.265.14', 'accessionYear': '1967', 'isPu
# 8 {'objectID': 9, 'isHighlight': False, 'accessionNumber': '67.265.15', 'accessionYear': '1967', 'isPu
# 9 {'objectID': 11, 'isHighlight': False, 'accessionNumber': '1979.486.2', 'accessionYear': '1979', 'is
# 10 {'objectID': 12, 'isHighlight': False, 'accessionNumber': '1979.486.7', 'accessionYear': '1979', 'is
# 11 {'objectID': 10, 'isHighlight': False, 'accessionNumber': '1979.486.3', 'accessionYear': '1979', 'is
# 12 {'objectID': 13, 'isHighlight': False, 'accessionNumber': '1979.486.4', 'accessionYear': '1979', 'is
# 13 {'objectID': 16, 'isHighlight': False, 'accessionNumber': '16.74.27', 'accessionYear': '1916', 'isPu
# 14 {'objectID': 15, 'isHighlight': False, 'accessionNumber': '16.74.49', 'accessionYear': '1916', 'isPu
# 15 {'objectID': 14, 'isHighlight': False, 'accessionNumber': '1979.486.5', 'accessionYear': '1979', 'is
# 16 {'objectID': 17, 'isHighlight': False, 'accessionNumber': '16.74.28', 'accessionYear': '1916', 'isPu
# 17 {'objectID': 19, 'isHighlight': False, 'accessionNumber': '16.74.30', 'accessionYear': '1916', 'isPu
# 18 {'objectID': 21, 'isHighlight': False, 'accessionNumber': '16.74.32', 'accessionYear': '1916', 'isPu
# 19 {'objectID': 22, 'isHighlight': False, 'accessionNumber': '16.74.43', 'accessionYear': '1916', 'isPu
# 20 {'objectID': 20, 'isHighlight': False, 'accessionNumber': '16.74.31', 'accessionYear': '1916', 'isPu
# 21 {'objectID': 25, 'isHighlight': False, 'accessionNumber': '16.74.34', 'accessionYear': '1916', 'isPu
# 22 {'objectID': 24, 'isHighlight': False, 'accessionNumber': '16.74.33', 'accessionYear': '1916', 'isPu
# 23 {'objectID': 26, 'isHighlight': False, 'accessionNumber': '16.74.35', 'accessionYear': '1916', 'isPu
# 24 {'objectID': 27, 'isHighlight': False, 'accessionNumber': '16.74.36', 'accessionYear': '1916', 'isPu
# 25 {'objectID': 18, 'isHighlight': False, 'accessionNumber': '16.74.29', 'accessionYear': '1916', 'isPu
# 26 {'objectID': 23, 'isHighlight': False, 'accessionNumber': '16.74.44', 'accessionYear': '1916', 'isPu
# 27 {'objectID': 29, 'isHighlight': False, 'accessionNumber': '16.74.39', 'accessionYear': '1916', 'isPu
# 28 {'objectID': 28, 'isHighlight': False, 'accessionNumber': '16.74.38', 'accessionYear': '1916', 'isPu
# 29 {'objectID': 30, 'isHighlight': False, 'accessionNumber': '16.74.37', 'accessionYear': '1916', 'isPu
# 30 {'objectID': 31, 'isHighlight': False, 'accessionNumber': '16.74.40', 'accessionYear': '1916', 'isPu
# 31 {'objectID': 32, 'isHighlight': False, 'accessionNumber': '09.9.15', 'accessionYear': '1909', 'isPub
# 32 {'objectID': 34, 'isHighlight': False, 'accessionNumber': '1970.289.6', 'accessionYear': '1970', 'is
# 33 {'objectID': 33, 'isHighlight': False, 'accessionNumber': '64.62', 'accessionYear': '1964', 'isPubli
# 34 {'objectID': 38, 'isHighlight': False, 'accessionNumber': '38.165.50', 'accessionYear': '1938', 'isP
# 35 {'objectID': 37, 'isHighlight': False, 'accessionNumber': '38.165.51', 'accessionYear': '1938', 'isP
# 36 {'objectID': 36, 'isHighlight': False, 'accessionNumber': '1976.319', 'accessionYear': '1976', 'isPu
# 37 {'objectID': 35, 'isHighlight': True, 'accessionNumber': '04.1a–c', 'accessionYear': '1904', 'isPubl
# 38 {'objectID': 39, 'isHighlight': False, 'accessionNumber': '18.11.10', 'accessionYear': '1918', 'isPu
# 39 {'objectID': 40, 'isHighlight': False, 'accessionNumber': '46.140.143', 'accessionYear': '1946', 'is
# 40 {'objectID': 41, 'isHighlight': False, 'accessionNumber': '46.140.864', 'accessionYear': '1946', 'is
# 41 {'objectID': 42, 'isHighlight': False, 'accessionNumber': '60.58.1', 'accessionYear': '1960', 'isPub
# 42 {'objectID': 44, 'isHighlight': False, 'accessionNumber': '10.125.444a', 'accessionYear': '1910', 'i
# 43 {'objectID': 47, 'isHighlight': False, 'accessionNumber': '10.125.445b', 'accessionYear': '1910', 'i
# 44 {'objectID': 45, 'isHighlight': False, 'accessionNumber': '10.125.444b', 'accessionYear': '1910', 'i
# 45 {'objectID': 43, 'isHighlight': False, 'accessionNumber': '60.58.2', 'accessionYear': '1960', 'isPub
# 46 {'objectID': 48, 'isHighlight': False, 'accessionNumber': '10.125.446a', 'accessionYear': '1910', 'i
# 47 {'objectID': 50, 'isHighlight': False, 'accessionNumber': '10.125.447a', 'accessionYear': '1910', 'i
# 48 {'objectID': 49, 'isHighlight': False, 'accessionNumber': '10.125.446b', 'accessionYear': '1910', 'i
# 49 {'objectID': 46, 'isHighlight': False, 'accessionNumber': '10.125.445a', 'accessionYear': '1910', 'i
# 50 {'objectID': 51, 'isHighlight': False, 'accessionNumber': '10.125.447b', 'accessionYear': '1910', 'i
# 51 {'objectID': 53, 'isHighlight': False, 'accessionNumber': '10.125.452b', 'accessionYear': '1910', 'i
# 52 {'objectID': 57, 'isHighlight': False, 'accessionNumber': '10.125.454b', 'accessionYear': '1910', 'i
# 53 {'objectID': 58, 'isHighlight': False, 'accessionNumber': '10.125.499a', 'accessionYear': '1910', 'i
# 54 {'objectID': 59, 'isHighlight': False, 'accessionNumber': '10.125.499b', 'accessionYear': '1910', 'i
# 55 {'objectID': 52, 'isHighlight': False, 'accessionNumber': '10.125.452a', 'accessionYear': '1910', 'i
# 56 {'objectID': 62, 'isHighlight': False, 'accessionNumber': '22.120.1', 'accessionYear': '1922', 'isPu
# 57 {'objectID': 56, 'isHighlight': False, 'accessionNumber': '10.125.454a', 'accessionYear': '1910', 'i
# 58 {'objectID': 63, 'isHighlight': False, 'accessionNumber': '22.120.2', 'accessionYear': '1922', 'isPu
# 59 {'objectID': 64, 'isHighlight': False, 'accessionNumber': '23.80.14', 'accessionYear': '1923', 'isPu
# 60 {'objectID': 68, 'isHighlight': False, 'accessionNumber': '30.120.83', 'accessionYear': '1930', 'isP
# 61 {'objectID': 65, 'isHighlight': False, 'accessionNumber': '23.80.15', 'accessionYear': '1923', 'isPu
# 62 {'objectID': 70, 'isHighlight': False, 'accessionNumber': '34.90.1', 'accessionYear': '1934', 'isPub
# 63 {'objectID': 71, 'isHighlight': False, 'accessionNumber': '34.90.2', 'accessionYear': '1934', 'isPub
# 64 {'objectID': 69, 'isHighlight': False, 'accessionNumber': '30.120.84', 'accessionYear': '1930', 'isP
# 65 {'objectID': 72, 'isHighlight': False, 'accessionNumber': '36.31.1', 'accessionYear': '1936', 'isPub
# 66 {'objectID': 73, 'isHighlight': False, 'accessionNumber': '36.31.2', 'accessionYear': '1936', 'isPub
# 67 {'objectID': 75, 'isHighlight': False, 'accessionNumber': '37.15.2', 'accessionYear': '1937', 'isPub
# 68 {'objectID': 74, 'isHighlight': False, 'accessionNumber': '37.15.1', 'accessionYear': '1937', 'isPub
# 69 {'objectID': 78, 'isHighlight': False, 'accessionNumber': '37.174.1', 'accessionYear': '1937', 'isPu
# 70 {'objectID': 76, 'isHighlight': False, 'accessionNumber': '37.46.1', 'accessionYear': '1937', 'isPub
# 71 {'objectID': 79, 'isHighlight': False, 'accessionNumber': '37.174.2', 'accessionYear': '1937', 'isPu
# 72 {'objectID': 84, 'isHighlight': False, 'accessionNumber': '41.160.340', 'accessionYear': '1941', 'is
# 73 {'objectID': 81, 'isHighlight': False, 'accessionNumber': '39.184.47', 'accessionYear': '1939', 'isP
# 74 {'objectID': 80, 'isHighlight': False, 'accessionNumber': '39.184.46', 'accessionYear': '1939', 'isP
# 75 {'objectID': 85, 'isHighlight': False, 'accessionNumber': '41.160.341', 'accessionYear': '1941', 'is
# 76 {'objectID': 77, 'isHighlight': False, 'accessionNumber': '37.46.2', 'accessionYear': '1937', 'isPub
# 77 {'objectID': 86, 'isHighlight': False, 'accessionNumber': '41.160.344', 'accessionYear': '1941', 'is
# 78 {'objectID': 88, 'isHighlight': False, 'accessionNumber': '41.160.346', 'accessionYear': '1941', 'is
# 79 {'objectID': 87, 'isHighlight': False, 'accessionNumber': '41.160.345', 'accessionYear': '1941', 'is
# 80 {'objectID': 90, 'isHighlight': False, 'accessionNumber': '41.160.372', 'accessionYear': '1941', 'is
# 81 {'objectID': 89, 'isHighlight': False, 'accessionNumber': '41.160.347', 'accessionYear': '1941', 'is
# 82 {'objectID': 91, 'isHighlight': False, 'accessionNumber': '41.160.373', 'accessionYear': '1941', 'is
# 83 {'objectID': 93, 'isHighlight': False, 'accessionNumber': '46.67.127', 'accessionYear': '1946', 'isP
# 84 {'objectID': 94, 'isHighlight': False, 'accessionNumber': '47.137.1', 'accessionYear': '1947', 'isPu
# 85 {'objectID': 92, 'isHighlight': False, 'accessionNumber': '46.67.126', 'accessionYear': '1946', 'isP
# 86 {'objectID': 95, 'isHighlight': False, 'accessionNumber': '47.137.2', 'accessionYear': '1947', 'isPu
# 87 {'objectID': 96, 'isHighlight': False, 'accessionNumber': '48.135.107', 'accessionYear': '1948', 'is
# 88 {'objectID': 97, 'isHighlight': False, 'accessionNumber': '48.135.108', 'accessionYear': '1948', 'is
# 89 {'objectID': 98, 'isHighlight': False, 'accessionNumber': '48.158.2', 'accessionYear': '1948', 'isPu
# 90 {'objectID': 101, 'isHighlight': False, 'accessionNumber': '49.73.5', 'accessionYear': '1949', 'isPu
# 91 {'objectID': 100, 'isHighlight': False, 'accessionNumber': '49.73.4', 'accessionYear': '1949', 'isPu
# 92 {'objectID': 103, 'isHighlight': False, 'accessionNumber': '1971.180.62b', 'accessionYear': '1971',
# 93 {'objectID': 99, 'isHighlight': False, 'accessionNumber': '48.158.3', 'accessionYear': '1948', 'isPu
# 94 {'objectID': 104, 'isHighlight': False, 'accessionNumber': '1980.499.4', 'accessionYear': '1980', 'i
# 95 {'objectID': 106, 'isHighlight': False, 'accessionNumber': '1984.134.1', 'accessionYear': '1984', 'i
# 96 {'objectID': 105, 'isHighlight': False, 'accessionNumber': '1980.499.5', 'accessionYear': '1980', 'i
# 97 {'objectID': 102, 'isHighlight': False, 'accessionNumber': '1971.180.62a', 'accessionYear': '1971',
# 98 {'objectID': 107, 'isHighlight': False, 'accessionNumber': '1984.134.2', 'accessionYear': '1984', 'i
# 99 {'objectID': 108, 'isHighlight': False, 'accessionNumber': '1989.120.1', 'accessionYear': '1989', 'i
