# %%
import os
from backoff import on_exception, expo
import json
import requests
from collections import Counter
from datetime import datetime
from ratelimit import limits, sleep_and_retry, RateLimitException
import time
import urllib.request
import asyncio
import aiohttp
import nest_asyncio
from async_timeout import timeout
from requests.exceptions import HTTPError

# %%
data_path = "D:\\METIS\\data\\"

met_objects = []

# %%
url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects'
response = requests.get(url, allow_redirects=False)
all_objects = json.loads(response.text)
objectIDs = all_objects['objectIDs']

# %%
len(objectIDs)
# Out:
# 474632

# %%
def get_object_details(object_id, img_url=True):
    url ='https://collectionapi.metmuseum.org/public/collection/v1/objects/{}'.format(object_id)
    response = requests.get(url, timeout=10)
    response_json = json.loads(response.text)
    met_objects.append(response_json)

# %%
met_objects = []

# %% [markdown]
# start = datetime.now()
#
# for i, object_id in enumerate(objectIDs):
#     if i % 1000 == 0:
#         with open(data_path + "images_saved.json", "w") as write_file:
#             json.dump(images_saved, write_file)
#
#         with open(data_path + "met_objects.json", "w") as write_file:
#             json.dump(met_objects, write_file)
#
#         print("{}: {} elapsed".format(i, datetime.now() - start))
#
#     try:
#         img_url = get_object_details(object_id)
#         get_image(object_id, img_url)
#
#     except:
#         pass
#    # print(i, object_id)

# %%
start = datetime.now()

for i, object_id in enumerate(objectIDs[52000:100000]):
    if i % 1000 == 0:
        with open(data_path + "all_objects_12-6_53-100.json", "w") as write_file:
            json.dump(met_objects, write_file)  
            
        print("{}: {} elapsed".format(i, datetime.now() - start))
            
    try:
        get_object_details(object_id, img_url=False)
        
    except:
        pass
# Out:
# 0: 0:00:00.008998 elapsed
# 1000: 0:03:47.932529 elapsed
# 2000: 0:07:33.311638 elapsed
# 3000: 0:11:19.743917 elapsed
# 4000: 0:15:04.912808 elapsed
# 5000: 0:19:05.946711 elapsed
# 6000: 0:22:45.262749 elapsed
# 7000: 0:26:35.598435 elapsed
# 8000: 0:30:22.614136 elapsed
# 9000: 0:34:09.246214 elapsed
# 10000: 0:37:56.302261 elapsed
# 11000: 0:42:02.853875 elapsed
# 12000: 0:46:19.241875 elapsed
# 13000: 0:51:02.870660 elapsed
# 14000: 0:55:28.124181 elapsed
# 15000: 0:59:44.430547 elapsed
# 16000: 1:04:07.933542 elapsed
# 17000: 1:08:47.042801 elapsed
# 18000: 1:13:15.674081 elapsed
# 19000: 1:17:59.465081 elapsed
# 20000: 1:22:31.224405 elapsed
# 21000: 1:26:53.774741 elapsed
# 22000: 1:31:45.819803 elapsed
# 23000: 1:36:46.822742 elapsed
# 24000: 1:41:28.686382 elapsed
# 25000: 1:46:12.025007 elapsed
# 26000: 1:50:46.375710 elapsed
# 27000: 1:55:27.232107 elapsed
# 28000: 2:00:20.408167 elapsed
# 29000: 2:05:54.043692 elapsed
# 30000: 2:11:26.123686 elapsed
# 31000: 2:16:03.036688 elapsed
# 32000: 2:20:33.512689 elapsed
# 33000: 2:25:27.254051 elapsed
# 34000: 2:30:24.734554 elapsed
# 35000: 2:35:43.302048 elapsed
# 36000: 2:41:02.642522 elapsed
# 37000: 2:46:36.672520 elapsed
# 38000: 2:52:14.499930 elapsed
# 39000: 2:57:18.563162 elapsed
# 40000: 3:02:25.089999 elapsed
# 41000: 3:07:42.190998 elapsed
# 42000: 3:13:10.236565 elapsed
# 43000: 3:18:43.629659 elapsed
# 44000: 3:24:43.619873 elapsed
# 45000: 3:30:32.816877 elapsed
# 46000: 3:36:09.619871 elapsed
# 47000: 3:41:15.204874 elapsed

# %%
with open(data_path + "all_objects_12-6_53-100.json", "w") as write_file:
    json.dump(met_objects, write_file)

# %%
print("Finished", datetime.now() - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8916f958633d> in <module>
# ----> 1 print(Finished, datetime.now() - start)
#
# NameError: name 'Finished' is not defined
