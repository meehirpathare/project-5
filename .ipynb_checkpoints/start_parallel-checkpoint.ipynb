# %%
import imghdr
from PIL import Image 
import os
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg 
import json
import numpy as np
from skimage import io
from helpers import (get_dims, color_distance, display_color, palette_distance, 
                     closest_on_palette, get_channel, get_dominant_color)
import math
from colorthief import ColorThief
from joblib import Parallel, delayed
import multiprocessing
from datetime import datetime
import asyncio
import os
# %matplotlib inline

# %%
data_path = os.getcwd() + "\\data\\"

# %%
palette = {
        'sky blue': (113, 213, 248),'ultramarine': (60, 124, 246),'medium blue': (15, 72, 175),'dark blue': (25, 42, 114),
        'violet': (33, 19, 70),'teal': (14, 67, 73),'green': (15, 66, 35),'leaf green': (88, 135, 31),
        'light green': (154, 193, 45), 'yellow': (255, 252, 35),'orange': (230, 156, 23),'dark orange': (235, 105, 21),
        'vermillion': (216, 68, 14),'red': (205, 19, 14),'fuchsia': (157, 52, 105),'purple': (107, 32, 86),
        'dark purple': (84, 20, 57),'dark grey': (110, 110, 110),'light grey': (220, 220, 220),'pale grey': (240, 240, 240)
        }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def closest_on_palette(input_color, palette):
    dists = palette_distance(input_color, palette)
    min_index = np.argmin(dists)
    return list(palette.keys())[min_index]  

def make_color_list(save=False, filename='all_colors.txt'):
    all_colors = -1 * np.ones((256**3), dtype=object)
    pos = 0
    
    for i in range(0, 256):
        for j in range(0,256):
            for k in range(0, 256):  
                all_colors[pos] = (i, j, k)
                pos += 1
    
    if save == True:
        with open(filename, 'w') as f:
            f.write(str(cmap))
    return all_colors

# %%
all_colors = make_color_list()

# %%
def make_color_map(i, color_list=all_colors, palette=palette):
    color = color_list[i]
    cmap[color] = closest_on_palette(color, palette)

# %%
all_colors = make_color_list()

# %%
cmap = {}
start = datetime.now()
for i in range(len(all_colors)):
    
    if i % 100000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_parallel.txt', 'w') as f:
            f.write(str(cmap
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
                    
print('loop finished')

# %%
with open(data_path + 'test_parallel.txt', 'w') as f:
            f.write(str(cmap))
# Out:
# 0: 0:00:00.001068 elapsed
# 100000: 0:00:13.603045 elapsed
# 200000: 0:00:25.288603 elapsed
# 300000: 0:00:39.849601 elapsed
# 400000: 0:00:56.825863 elapsed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cf6b760fdcf7> in <module>
#       7         with open(data_path + 'test_parallel.txt', 'w') as f:
#       8             f.write(str(cmap))
# ----> 9     cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
#      10
#      11 print('loop finished')
#
# <ipython-input-4-3595f7d38f7b> in wrapped(*args, **kwargs)
#       1 def background(f):
#       2     def wrapped(*args, **kwargs):
# ----> 3         return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)
#       4
#       5     return wrapped
#
# ~\anaconda3\lib\asyncio\base_events.py in run_in_executor(self, executor, func, *args)
#     781                 self._default_executor = executor
#     782         return futures.wrap_future(
# --> 783             executor.submit(func, *args), loop=self)
#     784
#     785     def set_default_executor(self, executor):
#
# ~\anaconda3\lib\concurrent\futures\thread.py in submit(*args, **kwargs)
#     186
#     187             self._work_queue.put(w)
# --> 188             self._adjust_thread_count()
#     189             return f
#     190     submit.__text_signature__ = _base.Executor.submit.__text_signature__
#
# ~\anaconda3\lib\concurrent\futures\thread.py in _adjust_thread_count(self)
#     201             q.put(None)
#     202
# --> 203         num_threads = len(self._threads)
#     204         if num_threads < self._max_workers:
#     205             thread_name = '%s_%d' % (self._thread_name_prefix or self,
#
# KeyboardInterrupt:
