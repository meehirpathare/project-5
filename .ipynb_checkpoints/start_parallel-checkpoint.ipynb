# %%
import imghdr
from PIL import Image 
import os
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg 
import json
import numpy as np
from skimage import io
from helpers import (get_dims, color_distance, display_color, palette_distance, 
                     closest_on_palette, get_channel, get_dominant_color)
import math
from colorthief import ColorThief
from joblib import Parallel, delayed
import multiprocessing
from datetime import datetime
import asyncio

# %matplotlib inline

# %%
data_path =  os.getcwd() + "\\data\\"
image_path = "D:\\METIS\\images\\"

# %%
palette = {
        'sky blue': (113, 213, 248),'ultramarine': (60, 124, 246),'medium blue': (15, 72, 175),'dark blue': (25, 42, 114),
        'violet': (33, 19, 70),'teal': (14, 67, 73),'green': (15, 66, 35),'leaf green': (88, 135, 31),
        'light green': (154, 193, 45), 'yellow': (255, 252, 35),'orange': (230, 156, 23),'dark orange': (235, 105, 21),
        'vermillion': (216, 68, 14),'red': (205, 19, 14),'fuchsia': (157, 52, 105),'purple': (107, 32, 86),
        'dark purple': (84, 20, 57),'dark grey': (110, 110, 110),'light grey': (220, 220, 220),'pale grey': (240, 240, 240)
        }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def closest_on_palette(input_color, palette):
    dists = palette_distance(input_color, palette)
    min_index = np.argmin(dists)
    return list(palette.keys())[min_index]  

def make_color_list(save=False, filename='all_colors.txt'):
    all_colors = -1 * np.ones((256**3), dtype=object)
    pos = 0
    
    for i in range(0, 256):
        for j in range(0,256):
            for k in range(0, 256):  
                all_colors[pos] = (i, j, k)
                pos += 1
    
    if save == True:
        with open(filename, 'w') as f:
            f.write(str(cmap))
    return all_colors

# %%
all_colors = make_color_list()

# %%
cmap = {}

# %%
start = datetime.now()
for i in range(4000000):
    
    if i % 100000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_0_to_4m.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
# Out:
# 0: 0:00:00 elapsed
# 100000: 0:00:08.082451 elapsed
# 200000: 0:00:18.504659 elapsed
# 300000: 0:00:28.946494 elapsed
# 400000: 0:00:39.675397 elapsed
# 500000: 0:00:53.115342 elapsed
# 600000: 0:01:05.935405 elapsed
# 700000: 0:01:21.745476 elapsed
# 800000: 0:01:36.202834 elapsed
# 900000: 0:01:54.904841 elapsed
# 1000000: 0:02:13.132583 elapsed
# 1100000: 0:02:38.260075 elapsed
# 1200000: 0:03:02.157676 elapsed
# 1300000: 0:03:25.420792 elapsed
# 1400000: 0:04:08.823478 elapsed
# 1500000: 0:04:40.174324 elapsed
# 1600000: 0:05:08.538991 elapsed
# 1700000: 0:06:42.780709 elapsed
# 1800000: 0:07:11.861770 elapsed
# 1900000: 0:07:47.773268 elapsed
# 2000000: 0:08:24.238614 elapsed
# 2100000: 0:09:00.000191 elapsed
# 2200000: 0:14:37.331649 elapsed
# 2300000: 0:15:57.629963 elapsed
# 2400000: 0:16:37.981828 elapsed
# 2500000: 0:17:18.182537 elapsed
# 2600000: 0:17:59.351570 elapsed
# 2700000: 0:29:37.669909 elapsed
# 2800000: 0:33:05.061353 elapsed
# 2900000: 0:35:51.855761 elapsed
# 3000000: 0:38:59.736911 elapsed
# 3100000: 0:41:47.650393 elapsed
# 3200000: 0:44:32.383900 elapsed
# 3300000: 1:03:52.121441 elapsed
# 3400000: 1:07:19.496121 elapsed
# 3500000: 1:09:42.676086 elapsed
# 3600000: 1:12:21.300321 elapsed
# 3700000: 1:15:34.056116 elapsed
# 3800000: 1:18:50.254715 elapsed
# 3900000: 1:22:07.649002 elapsed

# %%
for i in range(4000000, 8000000):
    
    if i % 100000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_4_to_8m.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)
# Out:
# 4000000: 1:26:05.963493 elapsed
# 4100000: 1:51:40.776006 elapsed
# 4200000: 1:56:23.462036 elapsed
# 4300000: 2:00:14.724495 elapsed
# 4400000: 2:03:54.709811 elapsed

# %%
for i in range(8000000, 12000000):
    
    if i % 100000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_8_to_12m.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)

# %%
for i in range(12000000, len(all_colors)):
    
    if i % 100000 == 0:
        print("{}: {} elapsed".format(i, datetime.now() - start))
        
        with open(data_path + 'test_12_to_end.txt', 'w') as f:
            f.write(str(cmap))
                        
    cmap[all_colors[i]] = closest_on_palette(all_colors[i], palette)

# %%
with open(data_path + 'rgb_closest.txt', 'w') as f:
            f.write(str(cmap))
        
print("Finished")
