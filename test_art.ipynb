# %%
# %matplotlib inline
from colorthief import ColorThief

# %%
from art import Art

art = Art()
print(art.attributes)
# Out:
# ['palette', 'channels', 'cmaps', 'color_list', 'data_path', 'image_path', 'num_colors', 'PIL', 'cv2', 'np', 'skimage', 'plt', 'mpimg', 'display', 'colormath']

# %%
img = art.load_img('test_image.jpg')

# %%
art.show_image(img)

# %%
new_img = art.resize(img, (1000, 1000))

# %%
art.show_image(new_img)

# %%
art.show_channel(img, channel='red')

# %%
art.show_rgb_channels(new_img)
